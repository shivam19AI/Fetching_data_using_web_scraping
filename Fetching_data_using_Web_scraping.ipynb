# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

webpage = requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers = headers).text

# %%
#webpage

# %%
soup  = BeautifulSoup(webpage, 'lxml')

# %%
#print(soup.prettify())

# %%
soup.find_all('h1')[0].text
# Out:
# 'List of companies in India'

# %%
soup.find_all('h2')
# Out:
# [<h2 class="company-name bold-title-l" title="TCS">
#  									TCS
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="Accenture">
#  									Accenture
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="Cognizant">
#  									Cognizant
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="ICICI Bank">
#  									ICICI Bank
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="HDFC Bank">
#  									HDFC Bank
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="Wipro">
#  									Wipro
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="Infosys">
#  									Infosys
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="Capgemini">
#  									Capgemini
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="Tech Mahindra">
#  									Tech Mahindra
#  								</h2>,
#  <h2 class="company-name bold-title-l" title="Genpact">
#  									Genpact
#  								</h2>,
# ...

# %%
len(soup.find_all('h2'))
# Out:
# 30

# %%
for i in soup.find_all('h2'):
    print(i.text)
# Out:
# 									TCS
#
#
# 									Accenture
#
#
# 									Cognizant
#
#
# 									ICICI Bank
#
#
# 									HDFC Bank
#
#
# 									Wipro
#
#
# 									Infosys
#
#
# 									Capgemini
#
#
# 									Tech Mahindra
#
#
# 									Genpact
#
#
# 									HCLTech
#
#
# 									Amazon
#
#
# 									Axis Bank
#
#
# 									Concentrix Corpo...
#
#
# 									IBM
#
#
# 									Reliance jio
#
#
# 									Larsen & Toubro ...
#
#
# 									HDB Financial Se...
#
#
# 									Vodafone Idea
#
#
# 									Teleperformance
#
#
# 									Reliance Retail
#
#
# 									Kotak Mahindra B...
#
#
# 									Deloitte
#
#
# 									Reliance Industr...
#
#
# 									Bharti Airtel
#
#
# 									BYJU'S
#
#
# 									Tata Motors
#
#
# 									Flipkart
#
#
# 									WNS
#
#
# 									IndusInd Bank

# %%
for i in soup.find_all('h2'):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# ICICI Bank
# HDFC Bank
# Wipro
# Infosys
# Capgemini
# Tech Mahindra
# Genpact
# HCLTech
# Amazon
# Axis Bank
# Concentrix Corpo...
# IBM
# Reliance jio
# Larsen & Toubro ...
# HDB Financial Se...
# Vodafone Idea
# Teleperformance
# Reliance Retail
# Kotak Mahindra B...
# Deloitte
# Reliance Industr...
# Bharti Airtel
# BYJU'S
# Tata Motors
# Flipkart
# WNS
# IndusInd Bank

# %%
for i in soup.find_all('p',class_ = 'rating'):
    print(i.text.strip())
# Out:
# 3.9
# 4.1
# 4.0
# 4.0
# 4.0
# 3.9
# 3.9
# 3.9
# 3.7
# 4.0
# 3.8
# 4.2
# 3.9
# 4.0
# 4.2
# 4.0
# 4.1
# 4.0
# 4.2
# 3.6
# 4.1
# 3.9
# 4.1
# 4.1
# 4.1
# 3.5
# 4.1
# 4.2
# 3.7
# 3.8

# %%
for i in soup.find_all('a',class_='review-count'):
    print(i.text.strip())
# Out:
# (52.7k Reviews)
# (33.5k Reviews)
# (30.8k Reviews)
# (34.7k Reviews)
# (40.8k Reviews)
# (30.1k Reviews)
# (29.4k Reviews)
# (24.9k Reviews)
# (22.4k Reviews)
# (20.1k Reviews)
# (19.3k Reviews)
# (19.6k Reviews)
# (19.2k Reviews)
# (15.5k Reviews)
# (15.7k Reviews)
# (15.2k Reviews)
# (24.9k Reviews)
# (13.8k Reviews)
# (13.4k Reviews)
# (14.9k Reviews)
# (17.5k Reviews)
# (13.9k Reviews)
# (10.7k Reviews)
# (46.3k Reviews)
# (12.7k Reviews)
# (13.8k Reviews)
# (12.2k Reviews)
# (12.4k Reviews)
# (7.2k Reviews)
# (6.9k Reviews)

# %%
len(soup.find_all('a',class_='review-count'))
# Out:
# 30

# %%
len(soup.find_all('i',class_='icon-domain'))
# Out:
# 30

# %%
soup = BeautifulSoup(webpage,'lxml')

# %%
company = soup.find_all('div',class_='company-content-wrapper')

# %%
len(company)
# Out:
# 30

# %%
name = []
rating =[]
reviews = []
c_type = []
hq = []
old = []
employees = []
for i in company:
    name.append(i.find('h2').text.strip())
    rating.append(i.find('p',class_='rating').text.strip())
    reviews.append(i.find('a',class_='review-count').text.strip())
    c_type.append(i.find_all('p',class_='infoEntity')[0].text.strip())
    hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
    old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
    try:
        employees.append(i.find_all('p',class_='infoEntity')[3].text.strip())
    except:
        employees.append(np.nan)
    
    
d = {'name':name, 'rating':rating, 'reviews':reviews,'type':c_type, 'hq':hq, 'old':old, 'employees':employees}
df = pd.DataFrame(d)

# %%
name
# Out:
# ['TCS',
#  'Accenture',
#  'Cognizant',
#  'ICICI Bank',
#  'HDFC Bank',
#  'Wipro',
#  'Infosys',
#  'Capgemini',
#  'Tech Mahindra',
#  'Genpact',
#  'HCLTech',
#  'Amazon',
#  'Axis Bank',
#  'Concentrix Corpo...',
#  'IBM',
#  'Reliance jio',
#  'Larsen & Toubro ...',
#  'HDB Financial Se...',
#  'Vodafone Idea',
#  'Teleperformance',
#  'Reliance Retail',
#  'Kotak Mahindra B...',
#  'Deloitte',
#  'Reliance Industr...',
#  'Bharti Airtel',
#  "BYJU'S",
#  'Tata Motors',
#  'Flipkart',
#  'WNS',
#  'IndusInd Bank']

# %%
rating
# Out:
# ['3.9',
#  '4.1',
#  '4.0',
#  '4.0',
#  '4.0',
#  '3.9',
#  '3.9',
#  '3.9',
#  '3.7',
#  '4.0',
#  '3.8',
#  '4.2',
#  '3.9',
#  '4.0',
#  '4.2',
#  '4.0',
#  '4.1',
#  '4.0',
#  '4.2',
#  '3.6',
#  '4.1',
#  '3.9',
#  '4.1',
#  '4.1',
#  '4.1',
#  '3.5',
#  '4.1',
#  '4.2',
#  '3.7',
#  '3.8']

# %%
reviews
# Out:
# ['(52.7k Reviews)',
#  '(33.5k Reviews)',
#  '(30.8k Reviews)',
#  '(34.7k Reviews)',
#  '(40.8k Reviews)',
#  '(30.1k Reviews)',
#  '(29.4k Reviews)',
#  '(24.9k Reviews)',
#  '(22.4k Reviews)',
#  '(20.1k Reviews)',
#  '(19.3k Reviews)',
#  '(19.6k Reviews)',
#  '(19.2k Reviews)',
#  '(15.5k Reviews)',
#  '(15.7k Reviews)',
#  '(15.2k Reviews)',
#  '(24.9k Reviews)',
#  '(13.8k Reviews)',
#  '(13.4k Reviews)',
#  '(14.9k Reviews)',
#  '(17.5k Reviews)',
#  '(13.9k Reviews)',
#  '(10.7k Reviews)',
#  '(46.3k Reviews)',
#  '(12.7k Reviews)',
#  '(13.8k Reviews)',
#  '(12.2k Reviews)',
#  '(12.4k Reviews)',
#  '(7.2k Reviews)',
#  '(6.9k Reviews)']

# %%
company[0].find_all('p',class_='infoEntity')
# Out:
# [<p class="infoEntity sbold-list-header"><i class="icon-domain"></i>
#  							Public
#  						</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-pin-drop"></i>
#  							Mumbai,Maharashtra + 275 more
#  						</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-access-time"></i>
#  							55 years old
#  						</p>,
#  <p class="infoEntity sbold-list-header"><i class="icon-supervisor-account"></i>
#  							1 Lakh+ Employees (India)
#  						</p>]

# %%
company[0].find_all('p',class_='infoEntity')[0].text.strip()
# Out:
# 'Public'

# %%
company[0].find_all('p',class_='infoEntity')[1].text.strip()
# Out:
# 'Mumbai,Maharashtra + 275 more'

# %%
company[0].find_all('p',class_='infoEntity')[2].text.strip()
# Out:
# '55 years old'

# %%
company[0].find_all('p',class_='infoEntity')[3].text.strip()
# Out:
# '1 Lakh+ Employees (India)'

# %%
df
# Out:
#                    name rating          reviews     type  \
# 0                   TCS    3.9  (52.7k Reviews)   Public
# 1             Accenture    4.1  (33.5k Reviews)   Public
# 2             Cognizant    4.0  (30.8k Reviews)  Private
# 3            ICICI Bank    4.0  (34.7k Reviews)   Public
# 4             HDFC Bank    4.0  (40.8k Reviews)   Public
# 5                 Wipro    3.9  (30.1k Reviews)   Public
# 6               Infosys    3.9  (29.4k Reviews)   Public
# 7             Capgemini    3.9  (24.9k Reviews)   Public
# 8         Tech Mahindra    3.7  (22.4k Reviews)   Public
# 9               Genpact    4.0  (20.1k Reviews)   Public
# 10              HCLTech    3.8  (19.3k Reviews)   Public
# 11               Amazon    4.2  (19.6k Reviews)   Public
# 12            Axis Bank    3.9  (19.2k Reviews)   Public
# 13  Concentrix Corpo...    4.0  (15.5k Reviews)   Public
# 14                  IBM    4.2  (15.7k Reviews)   Public
# ...

# %%
import numpy as np

# %%
import pandas as pd

# %%
final = pd.DataFrame()

for j in range(1,500):
    
    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'}

    webpage = requests.get(url,headers = headers).text
    soup = BeautifulSoup(webpage, 'lxml')
    company = soup.find_all('div',class_='company-content-wrapper')
    name=[]
    rating=[]
    reviews=[]
    ctype=[]
    hq=[]
    how_old=[]
    no_of_employee=[]

    for i in company:

        try:
            name.append(i.find('h2').text.strip())
        except:
            name.append(np.nan)

        try:
            rating.append(i.find('p',class_='rating').text.strip())
        except:
            rating.append(np.nan)
   
        try:

            reviews.append(i.find('a' , class_='review-count').text.strip())
        except:
            reviews.append(np.nan)

        try:

            ctype.append(i.find_all('p',class_='infoEntity')[0].text.strip())
        except:
            ctype.append(np.nan)
        try:

            hq.append(i.find_all('p',class_='infoEntity')[1].text.strip())
        except:
            hq.append(np.nan)
    
        try:

            how_old.append(i.find_all('p',class_='infoEntity')[2].text.strip())
        except:
            how_old.append(np.nan)
        try:
            no_of_employee.append(i.find_all('p',class_='infoEntity')[3].text.strip())
        except:
            no_of_employee.append(np.nan)
    

    df=pd.DataFrame({'name':name,'rating':rating,'reviews':reviews,'company_type':ctype,
    'Head_Quarters':hq,'Company_Age':how_old,'No_of_Employee':no_of_employee,
    })
  
    final=final.append(df,ignore_index=True)
# Out:
# C:\Users\kumar\AppData\Local\Temp\ipykernel_20928\2824248250.py:63: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   final=final.append(df,ignore_index=True)

# %%
final
# Out:
#                      name rating          reviews   company_type  \
# 0                     TCS    3.9  (53.2k Reviews)         Public
# 1               Accenture    4.1  (33.7k Reviews)         Public
# 2               Cognizant    4.0  (31.1k Reviews)        Private
# 3              ICICI Bank    4.0    (35k Reviews)         Public
# 4               HDFC Bank    4.0  (41.2k Reviews)         Public
# ...                   ...    ...              ...            ...
# 9983  The Global Green...    4.2     (53 Reviews)        Private
# 9984                LEONI    3.4     (53 Reviews)  Pune + 2 more
# 9985  Tantia Construct...    4.5     (53 Reviews)         Public
# 9986     THE Gate Academy    3.8     (53 Reviews)        Private
# 9987  Gimatex Industri...    4.3     (53 Reviews)        Private
#
#                                Head_Quarters   Company_Age  \
# 0              Mumbai,Maharashtra + 275 more  55 years old
# 1                          Dublin + 133 more  34 years old
# ...

# %%
final.shape
# Out:
# (9988, 7)

# %%
final.to_excel('company_data1.xlsx',index =False, sheet_name ='sheet1')
